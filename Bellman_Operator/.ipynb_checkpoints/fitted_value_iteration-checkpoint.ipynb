# %%
include("new_lin_interp.jl")
# Out:
# my_lin_interp (generic function with 1 method)

# %% [markdown]
# [contents](https://github.com/M-okb/fitted_value_iteration/blob/master/Bellman_Operator/new_lin_interp.jl)
#
# [前回作成したもの](https://github.com/M-okb/MyInterpolation.jl/blob/master/my_lin_interp.jl)ではout of rangeにおいてerror文を吐かせていたが、
#
#
#
# 今回はBellmanOperator()に繋げる都合上、range内の線の延長線上の値を返すように、変更を加えた。

# %%
#=
Solving the optimal growth problem via value function iteration.

@author : Spencer Lyon <spencer.lyon@nyu.edu>

@date : 2014-07-05

References
----------

Simple port of the file quantecon.models.optgrowth

http://quant-econ.net/jl/dp_intro.html
=#

#=
    This type defines the primitives representing the growth model. The
    default values are

        f(k) = k**alpha, i.e, Cobb-Douglas production function
        u(c) = ln(c), i.e, log utility

    See the constructor below for details
=#
using Optim
using Plots            
pyplot()
"""
Neoclassical growth model

##### Fields

- `f::Function` : Production function
- `bet::Real` : Discount factor in (0, 1)
- `u::Function` : Utility function
- `grid_max::Int` : Maximum for grid over savings values
- `grid_size::Int` : Number of points in grid for savings values
- `grid::LinSpace{Float64}` : The grid for savings values

"""
type GrowthModel
    f::Function
    bet::Float64
    u::Function
    grid_max::Int
    grid_size::Int
    grid::LinSpace{Float64}
end


default_f(k) = k^0.65
default_u(c) = log(c)

"""
Constructor of `GrowthModel`

##### Arguments

- `f::Function(k->k^0.65)` : Production function
- `bet::Real(0.95)` : Discount factor in (0, 1)
- `u::Function(log)` : Utility function
- `grid_max::Int(2)` : Maximum for grid over savings values
- `grid_size::Int(150)` : Number of points in grid for savings values

"""
function GrowthModel(f=default_f, bet=0.95, u=default_u, grid_max=2,
                     grid_size=150)
    grid = linspace(1e-6, grid_max, grid_size)
    return GrowthModel(f, bet, u, grid_max, grid_size, grid)
end

"""
Apply the Bellman operator for a given model and initial value.

##### Arguments

- `g::GrowthModel` : Instance of `GrowthModel`
- `w::Vector`: Current guess for the value function
- `out::Vector` : Storage for output.
- `;ret_policy::Bool(false)`: Toggles return of value or policy functions

##### Returns

None, `out` is updated in place. If `ret_policy == true` out is filled with the
policy function, otherwise the value function is stored in `out`.

"""
function bellman_operator!(g::GrowthModel, w::Vector, out::Vector;
                           ret_policy::Bool=false)
    # Apply linear interpolation to w
    Aw = my_lin_interp(g.grid, w)

    for (i, k) in enumerate(g.grid)
        objective(c) = - g.u(c) - g.bet * Aw(g.f(k) - c)
        res = optimize(objective, 1e-6, g.f(k))
        c_star = res.minimum

        if ret_policy
            # set the policy equal to the optimal c
            out[i] = c_star
        else
            # set Tw[i] equal to max_c { u(c) + beta w(f(k_i) - c)}
            out[i] = - objective(c_star)
        end
    end

    return out
end

function bellman_operator(g::GrowthModel, w::Vector;
                          ret_policy::Bool=false)
    out = similar(w)
    bellman_operator!(g, w, out, ret_policy=ret_policy)
end

"""
Extract the greedy policy (policy function) of the model.

##### Arguments

- `g::GrowthModel` : Instance of `GrowthModel`
- `w::Vector`: Current guess for the value function
- `out::Vector` : Storage for output

##### Returns

None, `out` is updated in place to hold the policy function

"""
function get_greedy!(g::GrowthModel, w::Vector, out::Vector)
    bellman_operator!(g, w, out, ret_policy=true)
end

get_greedy(g::GrowthModel, w::Vector) = bellman_operator(g, w, ret_policy=true)
                

                
function main(n::Int=35)
    gm = GrowthModel()
    w_init = 5 .* log(gm.grid) .- 25  # An initial condition -- fairly arbitrary
    w = copy(w_init)
    
    alpha = 0.65
    bet = gm.bet
    ab = alpha * bet
    c1 = (log(1 - ab) + log(ab) * ab / (1 - ab)) / (1 - bet)
    c2 = alpha / (1 - ab)
    v_star(k) = c1 .+ c2 .* log(k)
                    
    ws = Array(Any, n)
    colors = Array(RGBA, 1, n)
    for i=1:n
        w = bellman_operator(gm, w)
        ws[i] = w
        colors[i] = RGBA(1-i/n, 1-i/n, i/n, 1)
    end

    p = plot(gm.grid, w_init, color=:green, linewidth=2, alpha=0.6,
         label="initial condition")
    plot!(gm.grid, ws, color=colors, label="", linewidth=2)
    plot!(gm.grid, v_star(gm.grid), color=:blue, linewidth=2, alpha=0.8,
         label="true value function")
    plot!(ylims=(-40, -20), xlims=(minimum(gm.grid), maximum(gm.grid)))

    return p
end
# Out:
# WARNING: Method definition (::Type{Main.GrowthModel})(Function, Float64, Function, Int64, Int64, Base.LinSpace{Float64}) in module Main at In[10]:42 overwritten at In[12]:42.
# WARNING: Method definition (::Type{Main.GrowthModel})(Any, Any, Any, Any, Any, Any) in module Main at In[10]:42 overwritten at In[12]:42.
# WARNING: replacing docs for 'GrowthModel :: Union{}' in module 'Main'.
# WARNING: Method definition default_f(Any) in module Main at In[10]:51 overwritten at In[12]:51.
# WARNING: Method definition default_u(Any) in module Main at In[10]:52 overwritten at In[12]:52.
# WARNING: Method definition (::Type{Main.GrowthModel})() in module Main at In[10]:68 overwritten at In[12]:68.
# WARNING: Method definition (::Type{Main.GrowthModel})(Any) in module Main at In[10]:68 overwritten at In[12]:68.
# WARNING: Method definition (::Type{Main.GrowthModel})(Any, Any) in module Main at In[10]:68 overwritten at In[12]:68.
# WARNING: Method definition (::Type{Main.GrowthModel})(Any, Any, Any) in module Main at In[10]:68 overwritten at In[12]:68.
# WARNING: Method definition (::Type{Main.GrowthModel})(Any, Any, Any, Any) in module Main at In[10]:68 overwritten at In[12]:68.
# WARNING: Method definition (::Type{Main.GrowthModel})(Any, Any, Any, Any, Any) in module Main at In[10]:68 overwritten at In[12]:68.
# WARNING: replacing docs for 'GrowthModel :: Union{Tuple{Any,Any,Any,Any,Any},Tuple{Any,Any,Any,Any},Tuple{Any,Any,Any},Tuple{Any,Any},Tuple{Any},Tuple{}}' in module 'Main'.
# WARNING: Method definition bellman_operator!(Main.GrowthModel, Array{T<:Any, 1}, Array{T<:Any, 1}) in module Main at In[10]:91 overwritten at In[12]:91.
# WARNING: Method definition #bellman_operator!(Array{Any, 1}, Main.#bellman_operator!, Main.GrowthModel, Array{T<:Any, 1}, Array{T<:Any, 1}) in module Main overwritten.
# WARNING: replacing docs for 'bellman_operator! :: Tuple{GrowthModel,Array{T,1},Array{T,1}}' in module 'Main'.
# WARNING: Method definition bellman_operator(Main.GrowthModel, Array{T<:Any, 1}) in module Main at In[10]:112 overwritten at In[12]:112.
# WARNING: Method definition #bellman_operator(Array{Any, 1}, Main.#bellman_operator, Main.GrowthModel, Array{T<:Any, 1}) in module Main overwritten.
# WARNING: Method definition get_greedy!(Main.GrowthModel, Array{T<:Any, 1}, Array{T<:Any, 1}) in module Main at In[10]:131 overwritten at In[12]:131.
# WARNING: replacing docs for 'get_greedy! :: Tuple{GrowthModel,Array{T,1},Array{T,1}}' in module 'Main'.
# WARNING: Method definition get_greedy(Main.GrowthModel, Array{T<:Any, 1}) in module Main at In[10]:134 overwritten at In[12]:134.
# WARNING: Method definition main() in module Main at In[10]:139 overwritten at In[12]:139.
# WARNING: Method definition main(Int64) in module Main at In[10]:139 overwritten at In[12]:139.
# main (generic function with 2 methods)

# %%
main()
# Out:
# <img src="data:image/png;base64,..." />
